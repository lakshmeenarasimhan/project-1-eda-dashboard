# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/zomato.csv',encoding = 'latin-1')
df.shape
# Out:
# (51717, 17)

# %%
col_names = df.columns.tolist()
col_names
# Out:
# ['url',
#  'address',
#  'name',
#  'online_order',
#  'book_table',
#  'rate',
#  'votes',
#  'phone',
#  'location',
#  'rest_type',
#  'dish_liked',
#  'cuisines',
#  'approx_cost(for two people)',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
#percentage of missing values
(df.isnull().sum()/len(df)*100).round(2)
# Out:
# url                             0.00
# address                         0.00
# name                            0.00
# online_order                    0.00
# book_table                      0.00
# rate                           15.03
# votes                           0.00
# phone                           2.34
# location                        0.04
# rest_type                       0.44
# dish_liked                     54.29
# cuisines                        0.09
# approx_cost(for two people)     0.67
# reviews_list                    0.00
# menu_item                       0.00
# listed_in(type)                 0.00
# listed_in(city)                 0.00
# dtype: float64

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
#Summry
'''
1. Data Type Issues:
rate          → remove "/5", handle "NEW" and "-" → convert to float
approx_cost   → remove commas → convert to int
2. Useless Columns to Drop:
url           → just a web link
phone         → just a contact number
menu_item     → mostly empty lists
dish_liked    → 54% missing
3. Missing Values to Handle:
rate          → 15% missing → drop rows or fill
approx_cost   → 0.6% missing → drop rows
rest_type     → 227 missing → drop rows
cuisines      → 45 missing → drop rows
location      → 21 missing → drop rows
'''
